# %%
import os
import cv2

import pydicom
import pandas as pd
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 

from tqdm.notebook import tqdm

# %%
train = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/train.csv')

# %% [markdown]
# ## Decay theory
# Input for test:
#    * FVC in n week
#    * Percent in n week
#    * Age
#    * Sex
#    * Smoking status
#    * CT in n week
#
# Result:
#    * FVC in any week
#    * percent in any week
#
# $FVC = a.quantile(0.75) * (week - week_{test}) + FVC_{test}$
#
# $Confidence = Percent + a.quantile(0.75) * abs(week - week_{test}) $
#
# So let's try predict coefficient a.

# %%
train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker

# %%
train.SmokingStatus.unique()
# Out:
# array(['Ex-smoker', 'Never smoked', 'Currently smokes'], dtype=object)

# %%
def get_tab(df):
    vector = [(df.Age.values[0] - 30) / 30] 
    
    if df.Sex.values[0] == 'male':
       vector.append(0)
    else:
       vector.append(1)
    
    if df.SmokingStatus.values[0] == 'Never smoked':
        vector.extend([0,0])
    elif df.SmokingStatus.values[0] == 'Ex-smoker':
        vector.extend([1,1])
    elif df.SmokingStatus.values[0] == 'Currently smokes':
        vector.extend([0,1])
    else:
        vector.extend([1,0])
    return np.array(vector)

# %%
A = {} 
TAB = {} 
P = [] 
for i, p in tqdm(enumerate(train.Patient.unique())):
    sub = train.loc[train.Patient == p, :] 
    fvc = sub.FVC.values
    weeks = sub.Weeks.values
    c = np.vstack([weeks, np.ones(len(weeks))]).T
    a, b = np.linalg.lstsq(c, fvc)[0]
    
    A[p] = a
    TAB[p] = get_tab(sub)
    P.append(p)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   if __name__ == '__main__':

# %% [markdown]
# ## CNN for coeff prediction

# %%
def get_img(path):
    d = pydicom.dcmread(path)
    return cv2.resize(d.pixel_array / 2**11, (512, 512))

# %%
from tensorflow.keras.utils import Sequence

class IGenerator(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size=32):
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in train.Patient.values:
            self.train_data[p] = os.listdir(f'../input/osic-pulmonary-fibrosis-progression/train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size)
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0]
                img = get_img(f'../input/osic-pulmonary-fibrosis-progression/train/{k}/{i}')
                x.append(img)
                a.append(self.a[k])
                tab.append(self.tab[k])
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab)
        x = np.expand_dims(x, axis=-1)
        return [x, tab] , a

# %%
from tensorflow.keras.layers import (
    Dense, Dropout, Activation, Flatten, Input, BatchNormalization, GlobalAveragePooling2D, Add, Conv2D, AveragePooling2D, 
    LeakyReLU, ReLU,Concatenate 
)

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Nadam

def get_model(shape=(512, 512, 1)):
    '''
    def res_block(x, n_features):
        _x = x
        x = BatchNormalization()(x)
        x = ReLU(0)(x)
    
        x = Conv2D(n_features, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
        x = Add()([_x, x])
        return x
    '''
    inp = Input(shape=shape)
    def relu_bn(inputs):
        relu = ReLU()(inputs)
        bn = BatchNormalization()(relu)
        return bn
    def residual_block(x, downsample, filters, kernel_size: int = 3):
        y = Conv2D(kernel_size=kernel_size,
               strides= (1 if not downsample else 2),
                   filters=filters,
                   padding="same")(x)
        y = relu_bn(y)
        y = Conv2D(kernel_size=kernel_size,
                   strides=1,
                   filters=filters,
                   padding="same")(y)

        if downsample:
            x = Conv2D(kernel_size=1,
                       strides=2,
                       filters=filters,
                       padding="same")(x)
        out = Add()([x, y])
        out = relu_bn(out)
        return out
        
    
    num_filters = 8
    
    t = BatchNormalization()(inp)
    t = Conv2D(kernel_size=3,
               strides=1,
               filters=num_filters,
               padding="same")(t)
    t = relu_bn(t)
    
    num_blocks_list = [2, 2, 2, 2]
    for i in range(len(num_blocks_list)):
        num_blocks = num_blocks_list[i]
        for j in range(num_blocks):
            t = residual_block(t, downsample=(j==0 and i!=0),filters=num_filters)
        num_filters *= 2
    
    x = GlobalAveragePooling2D()(t)
    '''
    # 512
    x = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='same')(inp)
    x = BatchNormalization()(x)
    x = LeakyReLU(0.05)(x)
    
    x = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(0.05)(x)
    
    x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # 256
    x = Conv2D(8, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    for _ in range(2):
        x = res_block(x, 8)
    x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # 128
    x = Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    for _ in range(2):
        x = res_block(x, 16)
    x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # 64
    x = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    for _ in range(3):
        x = res_block(x, 32)
    x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # 32
    x = Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    for _ in range(3):
        x = res_block(x, 64)
    x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)    
    
    # 16
    x = Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    for _ in range(3):
        x = res_block(x, 128)
        
    # 16
    x = GlobalAveragePooling2D()(x)
    '''
    inp2 = Input(shape=(4,))
    x2 = tf.keras.layers.GaussianNoise(0.2)(inp2)
    x = Concatenate()([x, x2]) 
    x = Dropout(0.6)(x) 
    x = Dense(1)(x)
    #x2 = Dense(1)(x)
    return Model([inp, inp2] , x)

# %%
model = get_model() 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512, 512, 1)  4           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 8)  80          batch_normalization[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 512, 512, 8)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512, 512, 8)  32          re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 8)  584         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 512, 512, 8)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512, 512, 8)  32          re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 8)  584         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 512, 512, 8)  0           batch_normalization_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 512, 512, 8)  0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512, 512, 8)  32          re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 512, 512, 8)  584         batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 512, 512, 8)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512, 512, 8)  32          re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 8)  584         batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 512, 512, 8)  0           batch_normalization_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 512, 512, 8)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512, 512, 8)  32          re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 16) 1168        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 256, 256, 16) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 256, 16) 64          re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 16) 144         batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 16) 2320        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 16) 0           conv2d_7[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 256, 256, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 256, 16) 64          re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 16) 2320        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 256, 256, 16) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 16) 64          re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 16) 2320        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256, 256, 16) 0           batch_normalization_7[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 256, 256, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256, 256, 16) 64          re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 32) 4640        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 128, 128, 32) 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 32) 128         re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 32) 544         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 32) 9248        batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 32) 0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 128, 128, 32) 0           add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 32) 128         re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 32) 9248        batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 128, 128, 32) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 32) 128         re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 32) 9248        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 32) 0           batch_normalization_11[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 128, 128, 32) 0           add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 32) 128         re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   18496       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 64, 64, 64)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   2112        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 64)   36928       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 64)   0           conv2d_17[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 64, 64, 64)   0           add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 64, 64, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64)   256         re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   36928       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 64)   0           batch_normalization_15[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 64, 64, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 64)   256         re_lu_16[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# gaussian_noise (GaussianNoise)  (None, 4)            0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 68)           0           global_average_pooling2d[0][0]
#                                                                  gaussian_noise[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 68)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            69          dropout[0][0]
# ==================================================================================================
# Total params: 177,033
# Trainable params: 176,055
# Non-trainable params: 978
# __________________________________________________________________________________________________

# %%
from tensorflow_addons.optimizers import RectifiedAdam

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mae')

# %%
from sklearn.model_selection import train_test_split 

tr_p, vl_p = train_test_split(P, 
                              shuffle=True, 
                              train_size= 0.8)

# %%
import seaborn as sns

sns.distplot(list(A.values()));

# %%
er = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
model.fit_generator(IGenerator(keys=tr_p, 
                               a = A, 
                               tab = TAB), 
                    steps_per_epoch = 200,
                    validation_data=IGenerator(keys=vl_p, 
                               a = A, 
                               tab = TAB),
                    validation_steps = 20, 
                    callbacks = [er], 
                    epochs=1)
# Out:
# 200/200 [==============================] - 123s 615ms/step - loss: 5.3352 - val_loss: 6.9670

# %%
def score(fvc_true, fvc_pred, sigma):
    sigma_clip = np.maximum(sigma, 70)
    delta = np.abs(fvc_true - fvc_pred)
    delta = np.minimum(delta, 1000)
    sq2 = np.sqrt(2)
    metric = (delta / sigma_clip)*sq2 + np.log(sigma_clip* sq2)
    return np.mean(metric)

# %%
from tqdm.notebook import tqdm

metric = []
for q in tqdm(range(1, 10)):
    m = []
    for p in vl_p:
        x = [] 
        tab = [] 
        
        if p in ['ID00011637202177653955184', 'ID00052637202186188008618']:
            continue
        for i in os.listdir(f'../input/osic-pulmonary-fibrosis-progression/train/{p}/'):
            x.append(get_img(f'../input/osic-pulmonary-fibrosis-progression/train/{p}/{i}')) 
            tab.append(get_tab(train.loc[train.Patient == p, :])) 
        tab = np.array(tab) 
    
        x = np.expand_dims(x, axis=-1) 
        _a = model.predict([x, tab]) 
        a = np.quantile(_a, q / 10)
        
        percent_true = train.Percent.values[train.Patient == p]
        fvc_true = train.FVC.values[train.Patient == p]
        weeks_true = train.Weeks.values[train.Patient == p]
        
        fvc = a * (weeks_true - weeks_true[0]) + fvc_true[0]
        percent = percent_true[0] - a * abs(weeks_true - weeks_true[0])
        m.append(score(fvc_true, fvc, percent))
    print(np.mean(m))
    metric.append(np.mean(m))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))
# 8.24384250515458
# 8.24445656722373
# 8.244767699854657
# 8.245109386094857
# 8.245560887143753
# 8.24629469873756
# 8.247078624085367
# 8.248128535908382
# 8.248702940440849

# %% [markdown]
# ## Predict

# %%
q = (np.argmin(metric) + 1)/ 10
q
# Out:
# 0.1

# %%
sub = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/sample_submission.csv') 
sub.head()
# Out:
#                     Patient_Week   FVC  Confidence
# 0  ID00419637202311204720264_-12  2000         100
# 1  ID00421637202311550012437_-12  2000         100
# 2  ID00422637202311677017371_-12  2000         100
# 3  ID00423637202312137826377_-12  2000         100
# 4  ID00426637202313170790466_-12  2000         100

# %%
test = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/test.csv') 
test.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %%
A_test, B_test, P_test,W, FVC= {}, {}, {},{},{} 
STD, WEEK = {}, {} 
for p in test.Patient.unique():
    x = [] 
    tab = [] 
    for i in os.listdir(f'../input/osic-pulmonary-fibrosis-progression/test/{p}/'):
        x.append(get_img(f'../input/osic-pulmonary-fibrosis-progression/test/{p}/{i}')) 
        tab.append(get_tab(test.loc[test.Patient == p, :])) 
    tab = np.array(tab) 
            
    x = np.expand_dims(x, axis=-1) 
    _a = model.predict([x, tab]) 
    a = np.quantile(_a, q)
    A_test[p] = a
    B_test[p] = test.FVC.values[test.Patient == p] - a*test.Weeks.values[test.Patient == p]
    P_test[p] = test.Percent.values[test.Patient == p] 
    WEEK[p] = test.Weeks.values[test.Patient == p]

# %%
for k in sub.Patient_Week.values:
    p, w = k.split('_')
    w = int(w) 
    
    fvc = A_test[p] * w + B_test[p]
    sub.loc[sub.Patient_Week == k, 'FVC'] = fvc
    sub.loc[sub.Patient_Week == k, 'Confidence'] = (
        P_test[p] - A_test[p] * abs(WEEK[p] - w) 
)

# %%
sub[:20]
# Out:
#                      Patient_Week          FVC  Confidence
# 0   ID00419637202311204720264_-12  2982.147002   32.333857
# 1   ID00421637202311550012437_-12  2678.209476   21.254767
# 2   ID00422637202311677017371_-12  1890.382327   37.054820
# 3   ID00423637202312137826377_-12  3228.192758   13.451661
# 4   ID00426637202313170790466_-12  2898.446256   45.271224
# 5   ID00419637202311204720264_-11  2984.249946   34.436801
# 6   ID00421637202311550012437_-11  2680.460977   23.506268
# 7   ID00422637202311677017371_-11  1892.583308   39.255802
# 8   ID00423637202312137826377_-11  3230.461973   15.720876
# 9   ID00426637202313170790466_-11  2900.659068   47.484036
# 10  ID00419637202311204720264_-10  2986.352890   36.539745
# 11  ID00421637202311550012437_-10  2682.712478   25.757769
# 12  ID00422637202311677017371_-10  1894.784290   41.456784
# 13  ID00423637202312137826377_-10  3232.731188   17.990091
# 14  ID00426637202313170790466_-10  2902.871880   49.696848
# 15   ID00419637202311204720264_-9  2988.455835   38.642690
# 16   ID00421637202311550012437_-9  2684.963979   28.009270
# 17   ID00422637202311677017371_-9  1896.985272   43.657765
# 18   ID00423637202312137826377_-9  3235.000403   20.259306
# 19   ID00426637202313170790466_-9  2905.084692   51.909660

# %%
sub[["Patient_Week","FVC","Confidence"]].to_csv("submission.csv", index=False)
